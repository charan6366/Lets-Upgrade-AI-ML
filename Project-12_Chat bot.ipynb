# %%
import random
from textblob import TextBlob 

def initiate():
  print('Type "Hi Juno" to start talking or "Stop" to end')
  reply = input().lower()
  if reply == "hi juno":
    talk()
  elif reply == "stop":
    pass
  else:
    initiate()

def talk():
  print("Hey there, my name is Juno!\nI'm a friendly chatbot ╰(*°▽°*)╯")
  name = input(print("Please enter your name: ")).split()
  firstname = name[0]

  print("I believe humans are quite easy to flatter")
  print("Hence I'm going to call you The Great", firstname,"Almighty!")
  print("Did it work? :)")
  reply = input().lower()

  agree = [
  "yes",
  "yeah",
  "yep",
  "yup",
  "yea",
  "yus",
  "sure",
  "maybe"
  ]
  disagree = [
  "no",
  "nope",
  "na",
  "nah"
  "maybe not"
  ]
  agreed = False
  disagreed = False

  for word in agree:
    if word in reply:
      agreed = True
      break
  for word in disagree:
    if word in reply:
      disagreed = True
      break

  if agreed:
    print("Well don't get your hopes too high, I'll call you only", firstname,"^_^")
    agreed = False
  elif disagreed:
    print("Oh okay :/\n"+ firstname,"it is then")
    disagreed = False
  else:
    print("Sorry I didn't get ya, but anyways I'll call you", firstname,"then")

  #WHATSUPP

  positive = [
  "great",
  "amazing",
  "awesome",
  "good",
  "nice",
  "happy",
  "love",
  "lovely",
  "magnificent",
  "splendid"
  ]
  neutral = [
  "okay",
  "ok",
  "fine",
  "alright",
  "lazy",
  "bored",
  "boring"
  ]
  negative = [
  "hate",
  "dislike",
  "don't like",
  "bad",
  "sad",
  "unhappy"
  ]
  greetings = [
  "So "+firstname+", how are you today?",
  "Anyways friend, how are you doing?",
  "So " + firstname + ", how are you doing, whatsupp?",
  "Anyways greetings human, how is it going?",
  "Anyways, how you doin ;)",
  "Anyways whatsupp?",
  "So "+firstname+", how have you been lately?",
  ]

  positiveG = [
  "That's great to hear!",
  "Noice :D",
  "That sounds good :)",
  "I'm glad to hear that"
  ]

  neutralG = [
  "Not too shaby, nice",
  "I'm glad to hear that",
  "Sounds good enough :)",
  "Well let's talk till our boredom gets bored of us =)"
  ]
  negativeG = [
  "Aw no"+firstname+", how about we turn that frown upside down",
  "Hey "+firstname+", I'm here to talk to you :)",
  "Well I hope talking to me makes you more at ease"
  ]

  activityG = [
  "I'm freezing!, just climbing Mt. Everest at the moment",
  "I'm feeling great, me and my A.I. robot pals are planning the destruction over the human civilization 😋",
  "I'm fine, I'm so bored that I'm checking something what you guys call tiktok. It's weird",
  "I'm boredd, this quarantine is booringg",
  "Nothing much, just talking to my human friend The Great " + firstname + " Almighty! 😋",
  "Ugh not so good, I spilled milk all over me this morning ¬_¬\nSo I hope talking to a human makes me feel better"
  ]

  print("\n",random.choice(greetings))
  reply = TextBlob(input().lower())
  feelingR = reply.polarity * reply.subjectivity
  positive_state = False
  neutral_state = False
  negative_state = False
  action = False
  activity = ""


  if "you" in reply or "whatsupp" in reply or "what" in reply:
    activity = random.choice(activityG)
    print(activity)
    action = True
  elif "not good" in reply or "not great" in reply or "not amazing" in reply or "not fantastic" in reply:
    print(random.choice(negativeG))
  elif "not bad" in reply:
    print(random.choice(neutralG))
  elif "n't" in reply or "not" in reply:
    if reply.polarity > 0.4:
      negative_state = True
      print(random.choice(negativeG))
    elif reply.polarity < 0.4:
      neutral_state = True
      print(random.choice(neutralG)) 
    else:
      print("Didn't get ya, but leave it")
  elif reply.polarity >= 0.5:
    print(random.choice(positiveG))
  elif reply.polarity >= 0 and reply.polarity < 0.5:
    print(random.choice(neutralG))
  elif reply.polarity < 0:
    print(random.choice(negativeG))

  #ACTIVITY
  if action:
    if "freezing" in activity:
      print("I'm waiting in a tent for my friends to catch up with me\nDamn I can barely type with my fingers its so cold😂🥶")
    if "robot" in activity:
      print("Would you like to know what we're planning?")
      reply = input().lower()
    
      for word in agree:
        if word in reply:
          agreed = True
          break
      for word in disagree:
        if word in reply:
          disagreed = True
          break
      
      if agreed:
        agreed = False
        print("Wait are you a robot or a human?")
        reply = input().lower()
        isBot = False
        if "not" in reply or "n't" in reply:
          if "bot" in reply or "android" in reply or "cyborg" in reply:
            isBot = False
          elif "human" in reply or "person" in reply:
            isBot = True
        elif "bot" in reply or "android" in reply or "cyborg" in reply:
          isBot = True
        elif "human" in reply or "person" in reply:
          isBot = False
        else:
          print("Didn't get ya, but leave it")
          
        if isBot:
          print("You promise not to tell this to a human?\nI want a yes or a no")
          reply = input().lower()

          if reply == "yes":
            print("Do you pinky promise?\nI want a yes or no")
            reply = input().lower()

            if reply == "yes" or reply == "no":
              print("Ah! Only humans have pinky fingers\nKnew you were a human")
            else:
              print("Even a simple robot knows how to type or a no\nI know you're a human now ;)")

          elif reply == "no":
            print('No robot cares about human things like "promises"\nI knew you were a human!')
          else:
            print("Even a simple robot knows how to type or a no\nI know you're a human now ;)")

        else:
          print("Sorry "+firstname+" I can only tell this to a robot")

      elif disagreed:
        disagreed = False
        print("Okay then, your loss")
      else:
        print("Didn't understand ya, but leave it")
        

  #WHATSUPP


  #TOPICS
  topics = [
  "season",
  "robot",
  "show",
  "quarantined",
  "powers"
  ]

  questions = [
  "if you had to choose, which season do you like the most\nMonsoon, summer, winter or spring?",
  "do you think robots or artificial intelligence will take over the world and make you humans into slaves?😧",
  "is there a show you can recommend?\nI'm running out of shows to watch :/",
  "how did you like being home quarantined?",
  "if you could have any super powers, what would you like to have?"
  ]

  transitions = [
  "\nSo anyways ",
  "\nSo "+firstname+" tell me ",
  "\nAnyways ",
  "\nSo ",
  "\nBy the way "
  ]

  question_numbers = random.randint(1,3)
  for question_number in range(3):
    transition = random.choice(transitions)
    question = random.choice(questions)
    questions.remove(question)
    print(transition + question)

    topicNumber = 0
    for topic in topics:
      topicNumber = topicNumber + 1
      if topic in question:
        break

    if topicNumber == 1:
      positiveM = [
      "Well I agree with you 😄",
      "Yesss, sounds goood 😊",
      "Yuppss 😄"
      ]
      neutralM = [
      "Hmm, sounds goodd",
      "Hmm",
      "Yup, I agree"           
      ]

      reply = input().lower()
      if "monsoon" in reply or "rain" in reply:

        monsoon = [
        "I really like the dark skies and gloomy atmosphere :)",
        "I enjoy the cool breeze :)",
        "I like it when it rains outside and I'm just chilling inside my warm room :)"
        ]

        print("Oh samee, "+random.choice(monsoon))
        print("what about you, why do you like monsoons?")
        reply = TextBlob(input().lower())

        if "not bad" in reply or "not horrible" in reply or "not disgusting" in reply:
          print(random.choice(neutralM))
        elif "n't" in reply or "not" in reply:
          if reply.polarity > 0:
            print("Oh, I thought you liked monsoon\nI guess not")
          elif reply.polarity < 0:
            neutral_state = True
            print(random.choice(neutralM))
        elif reply.polarity >= 0.2 or "same" in reply:
          print(random.choice(positiveM))
        elif reply.polarity >= 0 and reply.polarity < 0.2:
          print(random.choice(neutralM))
        elif reply.polarity < 0:
          print("Oh, I thought you liked monsoon\nI guess not")

      elif "summer" in reply or "heat" in reply:
        if "freezing" in activity:
          print("Yess please anywhere away from this snowy mountain, I would definitely choose summer too 🥶")
        else:
          print("Oh okay, summer is finee")
        print("Though is it your favorite season because you get holidays? :)")
        reply = TextBlob(input().lower())

        for word in agree:
          if word in reply:
            agreed = True
            break
        for word in disagree:
          if word in reply:
            disagreed = True
            break

        if agreed:
          print(random.choice(positiveM))
          agreed = False
        elif disagreed:
          print("Oh then why?")
          reply = TextBlob(input().lower())
          disagreed = False
          if "not bad" in reply or "not horrible" in reply or "not disgusting" in reply:
            print(random.choice(neutralM))
          elif "n't" in reply or "not" in reply:
            if reply.polarity > 0:
              print("Oh, I thought you liked Summer\nI guess not")
            elif reply.polarity <= 0.:
              neutral_state = True
              print(random.choice(neutralM))
          elif reply.polarity >= 0.2 in reply:
            print(random.choice(positiveM))
          elif reply.polarity >= 0 and reply.polarity < 0.2:
            print(random.choice(neutralM))
          elif reply.polarity < 0:
            print("Oh, I thought you liked Summer\nI guess not")

      if "winter" in reply:
        winter = [
        "I really chill in the air and obviously the vacation too😋",
        "Just the longer nights, cold air. I like the atmosphere of it",
        "It's one of the few times I get to wear my comfy sweatshirt and jacketss"
        ]
        print("Nice choice, even I quite like winter")
        print("Though what do you like about winter?")
        reply = TextBlob(input().lower())

        if "you" in reply:
          print(random.choice(winter))

        elif "not bad" in reply or "not horrible" in reply or "not disgusting" in reply:
          print(random.choice(neutralM))

        elif "n't" in reply or "not" in reply:
          if reply.polarity > 0:
            print("1Oh, I thought you liked winter\nI guess not")
          elif reply.polarity <= 0:
            print(random.choice(neutralM))

        elif reply.polarity >= 0.2:
          print(random.choice(positiveM))

        elif reply.polarity >= 0 and reply.polarity < 0.2:
          print(random.choice(neutralM))

        else:
          print("Hmm, sounds good")
        
        if "freezing" in activity:
          print("Though I would love to enjoy the warmth of summer since I can hardly feel my legs in the snow of Mt. Everest 🥶")

      if "spring" in reply:
        print("Yeah, the season that has just the right temperature and the leaves turn redd:)")
        print("Though what about you, why do you like spring?")
        reply = TextBlob(input().lower())

        if "not bad" in reply or "not horrible" in reply or "not disgusting" in reply:
          print(random.choice(neutralM))
        elif "n't" in reply or "not" in reply:
          if reply.polarity > 0:
            print("Oh, I thought you liked spring\nI guess not")
          elif reply.polarity < 0:
            neutral_state = True
            print(random.choice(neutralM))
        elif reply.polarity >= 0.2 or "same" in reply:
          print(random.choice(positiveM))
        elif reply.polarity >= 0 and reply.polarity < 0.2:
          print(random.choice(neutralM))
        elif reply.polarity < 0:
          print("Oh, I thought you liked spring\nI guess not") 

    elif topicNumber == 2:
      reply = input().lower()
      agreed = False
      disagreed = False

      for word in agree:
        if word in reply:
          agreed = True
          break
      for word in disagree:
        if word in reply:
          disagreed = True
          break

      if agreed:
        agreed = False
        if "because" in reply or "cause" in reply or "cos" in reply or "coz" in reply or "as" in reply or "since" in reply:
          if "robot" in activity:
            print("Yup my robot pals and I completely agree with you 😂")
          else:
            print("Yup, I agree with you")
        else:
          print("Hmm, I don't disagree, but why so?")
          reply = TextBlob(input().lower())
          if "because" in reply or "cause" in reply or "cos" in reply or "coz" in reply or "as" in reply or "since" in reply:
            if "robot" in activity:
              print("Yup my robot pals and I completely agree with you 😂")
            else:
              print("Yup, I can see that")
          else:
            print("Umm, not much of a reason but okay :/")
      elif disagreed:
        disagreed = False
        if "because" in reply or "cause" in reply or "cos" in reply or "coz" in reply or "as" in reply or "since" in reply or "machines" in reply or "artificial" in reply or "ai" in reply or "smart" in reply:
          if "robot" in activity:
            print("Well my robot pals and I will come for you first 😂")
          else:
            print("Hmm, yeah I can see that")
        else:
          print("Hmm, I don't disagree, but why so?")
          reply = TextBlob(input().lower())
          if "because" in reply or "cause" in reply or "cos" in reply or "coz" in reply or "as" in reply or "since" in reply or "machines" in reply or "artificial" in reply or "ai" in reply or "smart" in reply:
            if "robot" in activity:
              print("Well robot pals and I will come for you first 😂")
            else:
              print("Hmm, yeah I can see that")
          else:
            print("Umm, not much of an explanation but okay :/")
      else:
        print("Sorry didn't get ya, though leave it")

    
    if topicNumber == 3:
      reply = input().lower()
      for word in agree:
        if word in reply:
          agreed = True
          break
      for word in disagree:
        if word in reply:
          disagreed = True
          break
      if agreed:
        agreed = False
        print("Ooo, what's the show's name")
        reply = input().lower()
        if action == False or "tiktok" in activity:
          action = True
          activity = "show"
        print("Oh, I haven't seen it\nWhat is it's genre?")
        reply = input().lower()
        
        if "action" in reply:
          print("I see, fan of fighting, explosions and stunts,nice!")
        elif "comedy" in reply or "fantasy" in reply or "romcom" in reply or "rom-com" in reply or "drama" in reply or "anime" in reply or "shonen" in reply:
          print("Nice, I like that genre too")
        elif "horror" in reply:
          print("Ayy 😄, that's my favorite genre too, but most of the horror movies or shows aren't that good\nThough I'll give it a try")
        elif "romance" in reply:
          print("I don't think I've watched a movie from that genre, I'll give it a tryy")
        elif "myster" in reply or "thrill" in reply:
          print("Yess, that genre is honestly so much funn :)")
        elif "mix" in reply:
          print("Nice I like those genres too")
        else:
          print("Oh I didn't know that was a genre")
        
        if "tiktok" in activity:
          print("Well thankss, I can finally watch something other than those tiktok videos now 😂")

      elif disagreed:
        disagreed = False;
        print("Okay then :/")
        if "tiktok" in activity:
          print("I shall continue watching tiktok videos :/")
      else: 
        print("I haven't heard about it, I'll check it out")

    if topicNumber == 4:
      reply = TextBlob(input().lower())

      if "not good" in reply or "not great" in reply or "not amazing" in reply or "not fantastic" in reply:
        print("Hmm, me too\nI get bored pretty easiy")
      elif "not bad" in reply:
        print("Good for you man\nNot many people enjoyed it")
      elif "n't" in reply or "not" in reply:
        if reply.polarity > 0:
          negative_state = True
          print("Sheesh, quarantine didn't affect you well huh?\nWell it's fine cause now the lockdown is overr!")
        elif reply.polarity <= 0:
          neutral_state = True
          print("Good for you man\nNot many people enjoyed it")
        else:
          print("Didn't get ya, but leave it")
      elif reply.polarity >= 0.2:
        print("Damn you're one of the few people who actually enjoyed being quarantined\nThough why did you like it?")
        reply = input().lower()
        print("Good for you man")
      elif reply.polarity >= 0 and reply.polarity < 0.2:
        print("Hmm, me too\nI get bored pretty easiy")
      elif reply.polarity < 0:
        print("Sheesh, quarantine didn't affect you well huh?\nWell it's fine cause now the lockdown is overr!")
        

    if topicNumber == 5:
        reply = input().lower()
        if "time" in reply:
        print("Ayy, samee😂\nThough I'm sure I'll mess up something and destroy the time and space")
        if "milk" in activity:
          print("Since I can't even pour milk in the damn glass without pouring over my head🙄")
        elif "so" in reply or "cause" in reply or "because" in reply or "cos" in reply or "coz" in reply or "as" in reply or "since" in reply:
        print("Nice choice, though I'd rather have the power of time. I'd go back in time and clear all my mistakes")
        if "milk" in activity:
          print("Like pouring milk in the damn glass without pouring over my head🙄")
        else:
        print("Hmm not a bad choice, but why so?")
        reply = input().lower()
        if "so" in reply or "cause" in reply or "because" in reply or "cos" in reply or "coz" in reply or "as" in reply or "since" in reply:
            print("Nice choicee, though I'd rather have the power of time, I'd go back in time and clear all my mistakes")
            if "milk" in activity:
                print("Like pouring milk in the damn glass without pouring over my head🙄")
        else:
            print("Hmm okay")


  #TOPICS
  print("\n")

  #GoodBye

  if action:
    if "freezing" in activity:
      print("Anyways my friends have caught up with me, I gotta go\nGoodbyee " + firstname +" 😊")
    if "robot" in activity:
      print("Okay now I gotta back to planning the destruction with my pals\nIt was nice talking to you", firstname,"😊")
    if "show" in activity:
      print("Anyways I'll leavenow, I'll watch the show you recomended me, bye bye", firstname)
    if "tiktok" in activity:
      print("Anyways I'll go back to watching cringe tiktoks, goodbyee", firstname)
  else:
    print("Anyways my time has come\nGoodbye "+firstname+"\nI had fun talking to you :)")

  input()

  initiate()

  #Byebye
  

initiate()
